# %%
import os, sys
import uuid
import networkx as nx

# %%
sys.path.append(os.path.join(os.getcwd(), 'structures'))
from structures.graph import Graph

# %%
g = Graph()

g.add_edge(uuid.uuid4(), uuid.uuid4())
print(g.__repr__())
# Out:
# Graph(directed=False, |V|=2, |E|=2)

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 3
#       1 # plot graph g
#       2 nx_graph = nx.Graph()
# ----> 3 for edge in g.edges:
#       4     nx_graph.add_edge(edge[0], edge[1])
#       5 nx.draw(nx_graph, with_labels=True)
#
# AttributeError: 'Graph' object has no attribute 'edges'
